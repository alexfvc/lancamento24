# %%
# !pip install chromium-browser
# !pip install chromium-chromedriver
# !pip install --upgrade selenium
# !pip install webdriver-manager
# Out:
# ERROR: Could not find a version that satisfies the requirement chromium-browser (from versions: none)
# ERROR: No matching distribution found for chromium-browser
# ERROR: Could not find a version that satisfies the requirement chromium-chromedriver (from versions: none)
# ERROR: No matching distribution found for chromium-chromedriver

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import pandas as pd
import warnings
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

# %%
# Automatiza a instalação do webdriver.

servico = Service(ChromeDriverManager().install())
#nav = webdriver.Chrome(service=servico)

# %%
tabela = pd.read_excel("planejamento.xlsx", sheet_name="preencher")
# Out:
# c:\Users\alexf\OneDrive\Documentos\GitHub\lancamento2024\lancamento2024\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)

# %%
tabela["Data"] = tabela["Data"].dt.strftime("%d/%m/%Y")
tabela["Id"] = tabela["Id"].astype(str)

# %%
tabela.head()
# Out:
#   EtapadaMatrícula               Turma         Id Disciplina  Turno  \
# 0           1º ano  1º EM REG 4 (2024)  1783756.0     Física  Manhã
# 1           1º ano  1º EM REG 4 (2024)  1783756.0     Física  Manhã
# 2           1º ano  1º EM REG 4 (2024)  1783756.0     Física  Manhã
# 3           1º ano  1º EM REG 4 (2024)  1783756.0     Física  Manhã
# 4           1º ano  1º EM REG 4 (2024)  1783756.0     Física  Manhã
#
#                                 Escola     Bimestre        Data  \
# 0  Avenida Delvito Alves da Silva, 888  2º BIMESTRE  26/04/2024
# 1  Avenida Delvito Alves da Silva, 888  2º BIMESTRE  03/05/2024
# 2  Avenida Delvito Alves da Silva, 888  2º BIMESTRE  10/05/2024
# 3  Avenida Delvito Alves da Silva, 888  2º BIMESTRE  17/05/2024
# 4  Avenida Delvito Alves da Silva, 888  2º BIMESTRE  24/05/2024
#
#                  ConteudoLecionado  \
# 0               movimento uniforme
# 1         função horária do espaço
# 2            exercícios e correção
# 3  movimento uniformimente variado
# 4            exercícios e correção
#
#                                             truncado
# 0  1º EM REG 4 (2024) - Física - Manhã - Avenida ...
# 1  1º EM REG 4 (2024) - Física - Manhã - Avenida ...
# 2  1º EM REG 4 (2024) - Física - Manhã - Avenida ...
# 3  1º EM REG 4 (2024) - Física - Manhã - Avenida ...
# 4  1º EM REG 4 (2024) - Física - Manhã - Avenida ...

# %%
class newbot:
    def __init__(self):
        options = webdriver.ChromeOptions()
        self.driver = webdriver.Chrome(options=options, service=servico)

    def driver(self):
        options = webdriver.ChromeOptions()
        driver = webdriver.Chrome(options=options)

    def diario_escolar_login(self):
        print("preencha os campos com seu login, senha e o capchat na pagina do diario que acabou de abrir. \nNAO CLICK EM ENTRAR")          
        site = 'https://dedmais.educacao.mg.gov.br/'
        self.driver.get(site)                                                                                                       
        ja = input("digite  's'  ao terminar:\n ('x' para fechar)\n ")
        if ja == "s":
            self.driver.find_element(by=By.XPATH, value='/html/body/div[1]/div/div/div[1]/div[3]/div[3]/div/div[2]/div/form/div[4]/button[2]').click()                #click em entrar
            self.driver.implicitly_wait(5)    
        elif ja == "x":
            self.driver.close()
        else:
            bott = newbot()
            bott.diario_escolar_login()

# %%
bot = newbot()
bot.diario_escolar_login()
# https://chromedriver.chromium.org/downloads (124.0.6367.61)
# Out:
# preencha os campos com seu login, senha e o capchat na pagina do diario que acabou de abrir.
# NAO CLICK EM ENTRAR

# %%
def select_turma():
    cards = bot.driver.find_elements(by=By.CLASS_NAME, value="v-card-text")
    df_cards = pd.DataFrame(columns=['EtapadaMatrícula','Turma','Escola','Disciplina','Turno', 'ElementoWeb'])	
    
    button = bot.driver.find_elements(by=By.CLASS_NAME, value="v-btn")

    sleep(2)
    cards = bot.driver.find_elements(by=By.CLASS_NAME, value="v-card-text")                                                                                     #monta o df_cards
    bot.driver.implicitly_wait(5)
    list_card = cards[i].text.split("\n")
    list_card.append(cards[i])
    df_cards.loc[len(df_cards)] = list_card
    df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
    bot.driver.implicitly_wait(5)
    cards[i].click()
    global contador
    contador = 0
    #sleep(2)

# %%
select_turma()
# Out:
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# C:\Users\alexf\AppData\Local\Temp\ipykernel_17244\4232825347.py:14: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_cards["Turma"][i] = df_cards["Turma"][i].split(" - ")[0]
# movimento uniforme 26/04/2024 1º EM REG 4 (2024)
# função horária do espaço 03/05/2024 1º EM REG 4 (2024)
# exercícios e correção 10/05/2024 1º EM REG 4 (2024)
# movimento uniformimente variado 17/05/2024 1º EM REG 4 (2024)
# exercícios e correção 24/05/2024 1º EM REG 4 (2024)
# revisão para prova 07/06/2024 1º EM REG 4 (2024)
# prova 14/06/2024 1º EM REG 4 (2024)
# recuperação  21/06/2024 1º EM REG 4 (2024)
# entrega de resultado 28/06/2024 1º EM REG 4 (2024)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 select_turma()
#
# Cell In[10], line 11, in select_turma()
#       9 cards = bot.driver.find_elements(by=By.CLASS_NAME, value="v-card-text")                                                                                     #monta o df_cards
#      10 bot.driver.implicitly_wait(5)
# ---> 11 list_card = cards[i].text.split("\n")
#      12 list_card.append(cards[i])
#      13 df_cards.loc[len(df_cards)] = list_card
#
# IndexError: list index out of range

# %%
bot.driver.close()
